# %% [markdown]
# # Pandas
#
# Pandas é atualmente uma das bibliotecas mais importantes na área da análise de dados

# %% [markdown]
# ### Importando o pandas

# %%
import pandas as pd

# %% [markdown]
# ### Criando um dataframe a partir de um dicionário

# %%
import pandas as pd
# dataframe = pd.DataFrame()
venda = {'data': ['15/02/2021', '16/02/2021'],
        'valor': [500, 300],
        'produto': ['feijao', 'arroz'],
        'qtde': [50, 70]
}
vendas_df = pd.DataFrame(venda)

# %% [markdown]
# ### Visualização dos Dados
# `print(df)` vs `display(df)`

# %%
display(vendas_df)
# Out:
#          data  valor produto  qtde
# 0  15/02/2021    500  feijao    50
# 1  16/02/2021    300   arroz    70

# %% [markdown]
# ### Importando arquivos e bases de dados

# %%
import pandas as pd
vendas_df = pd.read_excel("Vendas.xlsx")
display(vendas_df)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# 1               2             180          360
# 2               1             368          368
# 3               3             200          600
# 4               1              71           71
# ...           ...             ...          ...
# 93905           2             283          566
# 93906           2              79          158
# 93907           3              67          201
# 93908           5             114          570
# 93909           4             259         1036
#
# [93910 rows x 7 columns]

# %% [markdown]
# ### Alguns parâmetros que nos ajudam a ver os dados
# ```
# .head(n)
# .shape
# .describe()
# ```

# %%
display(vendas_df.head(10))
print(vendas_df.shape)
display(vendas_df.describe())
# Out:
#    Código Venda       Data                     ID Loja  \
# 0             1 2019-01-01          Iguatemi Esplanada
# 1             1 2019-01-01          Iguatemi Esplanada
# 2             1 2019-01-01          Iguatemi Esplanada
# 3             2 2019-01-02              Norte Shopping
# 4             2 2019-01-02              Norte Shopping
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza
# 6             5 2019-01-02              Shopping Barra
# 7             6 2019-01-02         Shopping Ibirapuera
# 8             7 2019-01-02              Norte Shopping
# 9             7 2019-01-02              Norte Shopping
#
#                   Produto  Quantidade  Valor Unitário  Valor Final
# 0          Sapato Estampa           1             358          358
# 1                Camiseta           2             180          360
# 2           Sapato Xadrez           1             368          368
# 3                 Relógio           3             200          600
# 4            Chinelo Liso           1              71           71
# 5             Cinto Linho           1             248          248
# 6                   Calça           1             170          170
# 7           Polo Listrado           4             149          596
# 8  Camisa Gola V Listrado           1             116          116
# 9             Camisa Liso           1             105          105
# (93910, 7)
#        Código Venda                           Data    Quantidade  \
# count  93910.000000                          93910  93910.000000
# mean   32464.762155  2019-06-16 23:52:28.265360896      2.166553
# min        1.000000            2019-01-01 00:00:00      1.000000
# 25%    16204.000000            2019-03-26 00:00:00      1.000000
# 50%    32367.000000            2019-06-17 00:00:00      2.000000
# 75%    48793.750000            2019-09-08 00:00:00      3.000000
# max    65014.000000            2019-11-30 00:00:00      5.000000
# std    18809.007093                            NaN      1.258732
#
#        Valor Unitário   Valor Final
# count    93910.000000  93910.000000
# mean       191.725886    414.862656
# min         30.000000     30.000000
# 25%        100.000000    156.000000
# 50%        155.000000    274.000000
# 75%        248.000000    524.000000
# max        750.000000   3750.000000
# std        145.215519    434.846228

# %% [markdown]
# ### Pegando colunas e algumas dicas

# %%
produtos = vendas_df[['Produto', 'ID Loja']]
display(produtos)
ids = vendas_df['ID Loja'].unique()
print(ids)
n_ids = vendas_df['ID Loja'].nunique()
display(n_ids)
# Out:
#                  Produto                     ID Loja
# 0         Sapato Estampa          Iguatemi Esplanada
# 1               Camiseta          Iguatemi Esplanada
# 2          Sapato Xadrez          Iguatemi Esplanada
# 3                Relógio              Norte Shopping
# 4           Chinelo Liso              Norte Shopping
# ...                  ...                         ...
# 100994    Short Listrado  Center Shopping Uberlândia
# 100995           Mochila  Center Shopping Uberlândia
# 100996  Pulseira Estampa  Center Shopping Uberlândia
# 100997   Camisa Listrado           Ribeirão Shopping
# 100998       Short Linho           Ribeirão Shopping
#
# [100999 rows x 2 columns]
# ['Iguatemi Esplanada' 'Norte Shopping' 'Rio Mar Shopping Fortaleza'
#  'Shopping Barra' 'Shopping Ibirapuera' 'Iguatemi Campinas'
#  'Shopping Center Leste Aricanduva' 'Passei das Águas Shopping'
#  'Shopping Recife' 'Shopping Midway Mall' 'Bourbon Shopping SP'
#  'Shopping Center Interlagos' 'Parque Dom Pedro Shopping'
#  'Center Shopping Uberlândia' 'Shopping União de Osasco'
#  'Shopping Eldorado' 'Shopping Vila Velha' 'Novo Shopping Ribeirão Preto'
#  'Rio Mar Recife' 'Palladium Shopping Curitiba' 'Shopping SP Market'
#  'Ribeirão Shopping' 'Shopping Iguatemi Fortaleza' 'Shopping Morumbi'
#  'Salvador Shopping']
# 25

# %% [markdown]
# ### Selecionando coisas com `.loc[...]`
#
# - Pegar 1 linha
# - Pegar linhas de acordo com alguma condição
# - Pegar linhas e colunas específicas
# - Pegar 1 valor específico
#
# Essas lógicas podem ser misturadas

# %%
# pegar uma linha
display(vendas_df.loc[6])

# pegar um interválo de linhas
display(vendas_df.loc[1:5])

# mostra linhas em que a codição é satisfeita
vendas_norteshopping_df = vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping']

# pegar várias linhas e colunas usando o loc
vendas_norteshopping_df = vendas_df.loc[vendas_df['ID Loja'] == 'Norte Shopping', ["ID Loja", "Produto", "Quantidade"]]
display(vendas_norteshopping_df)

# pegar 1 valor específico
print(vendas_df.loc[1, 'Produto'])
# Out:
# Código Venda                        5
# Data              2019-01-02 00:00:00
# ID Loja                Shopping Barra
# Produto                         Calça
# Quantidade                          1
# Valor Unitário                    170
# Valor Final                       170
# Comissão                          8.5
# Imposto                             0
# Name: 6, dtype: object
#    Código Venda       Data                     ID Loja        Produto  \
# 1             1 2019-01-01          Iguatemi Esplanada       Camiseta
# 2             1 2019-01-01          Iguatemi Esplanada  Sapato Xadrez
# 3             2 2019-01-02              Norte Shopping        Relógio
# 4             2 2019-01-02              Norte Shopping   Chinelo Liso
# 5             3 2019-01-02  Rio Mar Shopping Fortaleza    Cinto Linho
#
#    Quantidade  Valor Unitário  Valor Final  Comissão  Imposto
# 1           2             180          360     18.00        0
# 2           1             368          368     18.40        0
# 3           3             200          600     30.00        0
# 4           1              71           71      3.55        0
# 5           1             248          248     12.40        0
#               ID Loja                 Produto  Quantidade
# 3      Norte Shopping                 Relógio           3
# 4      Norte Shopping            Chinelo Liso           1
# 8      Norte Shopping  Camisa Gola V Listrado           1
# 9      Norte Shopping             Camisa Liso           1
# 100    Norte Shopping            Cueca Xadrez           5
# ...               ...                     ...         ...
# 93716  Norte Shopping             Polo Xadrez           1
# 93754  Norte Shopping              Calça Liso           1
# 93755  Norte Shopping          Casaco Estampa           2
# 93756  Norte Shopping                   Gorro           2
# 93852  Norte Shopping           Bermuda Linho           1
#
# [3924 rows x 3 columns]
# Camiseta

# %% [markdown]
# ### Adicionar 1 coluna e alterar arquivo original

# %%
# a partir de uma coluna que existe
vendas_df['Comissão'] = vendas_df['Valor Final'] * 0.05
# display(vendas_df)

# criar uma coluna com valor padrão
vendas_df.loc[:, "Imposto"] = 0
display(vendas_df)

# adicionando dados de volta no Excel
vendas_df.to_excel("Vendas2.xlsx", index=False)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final  Comissão  Imposto
# 0               1             358          358     17.90        0
# 1               2             180          360     18.00        0
# 2               1             368          368     18.40        0
# 3               3             200          600     30.00        0
# 4               1              71           71      3.55        0
# ...           ...             ...          ...       ...      ...
# 93905           2             283          566     28.30        0
# 93906           2              79          158      7.90        0
# 93907           3              67          201     10.05        0
# 93908           5             114          570     28.50        0
# 93909           4             259         1036     51.80        0
#
# [93910 rows x 9 columns]

# %% [markdown]
# ### Adicionar 1 linha
#
# Juntando bases de dados 'parecidas'

# %%
import pandas as pd
vendas_df = pd.read_excel("Vendas.xlsx")
vendas_dez_df = pd.read_excel("Vendas - Dez.xlsx")
#display(vendas_dez_df)

vendas_df = pd.concat([vendas_df, vendas_dez_df], ignore_index=True)
display(vendas_df)
# Out:
#         Código Venda       Data                     ID Loja           Produto  \
# 0                  1 2019-01-01          Iguatemi Esplanada    Sapato Estampa
# 1                  1 2019-01-01          Iguatemi Esplanada          Camiseta
# 2                  1 2019-01-01          Iguatemi Esplanada     Sapato Xadrez
# 3                  2 2019-01-02              Norte Shopping           Relógio
# 4                  2 2019-01-02              Norte Shopping      Chinelo Liso
# ...              ...        ...                         ...               ...
# 100994         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 100995         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 100996         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 100997         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 100998         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#         Quantidade  Valor Unitário  Valor Final
# 0                1             358          358
# 1                2             180          360
# 2                1             368          368
# 3                3             200          600
# 4                1              71           71
# ...            ...             ...          ...
# 100994           2             102          204
# 100995           4             270         1080
# 100996           1              87           87
# 100997           1             108          108
# 100998           2             133          266
#
# [100999 rows x 7 columns]

# %% [markdown]
# ### Excluir linhas e colunas

# %%
vendas_df = vendas_df.drop(0, axis=0) # sem o axis o padrão é 0
# axis = 0 -> linhas
# axis = 1 -> colunas
display(vendas_df)

# %% [markdown]
# ### Valores Vazios
# - Deletar linhas/colunas vazias
# - Deletar linhas que possuem valores vazios
# - Preencher valores vazios (média e último valor)

# %%
# deletar linhas e colunas completamente vazias
# vendas_df = vendas_df.dropna(how='all', axis=1)

# deletar linhas que possuem pelo menos 1 valor vazio
# vendas_df = vendas_df.dropna()

# média de valores da coluna
print(vendas_df['Comissão'].mean())

# preencher valores vazios
# preencher com 0
# vendas_df['Comissão'] = vendas_df['Comissão'].fillna(0)

# preencher com a média da coluna
vendas_df['Comissão'] = vendas_df['Comissão'].fillna(vendas_df['Comissão'].mean())
display(vendas_df)

# preencher com o último valor
vendas_df = vendas_df.ffill()

# %% [markdown]
# ### Calcular Indicadores
#
# - Groupby
# - Value counts

# %%
# value counts
transacoes_loja = vendas_df['ID Loja'].value_counts()
display(transacoes_loja)

# group by
faturamento_produto = vendas_df[['ID Loja', 'Valor Final']].groupby('ID Loja').sum()
display(faturamento_produto)
# Out:
# ID Loja
# Shopping Vila Velha                 4234
# Palladium Shopping Curitiba         4210
# Norte Shopping                      4179
# Rio Mar Shopping Fortaleza          4118
# Bourbon Shopping SP                 4116
# Iguatemi Campinas                   4108
# Rio Mar Recife                      4099
# Shopping Center Leste Aricanduva    4093
# Shopping SP Market                  4080
# Shopping Ibirapuera                 4051
# Novo Shopping Ribeirão Preto        4049
# Ribeirão Shopping                   4048
# Salvador Shopping                   4030
# Shopping Iguatemi Fortaleza         4021
# Shopping Center Interlagos          4021
# Center Shopping Uberlândia          4013
# Shopping Eldorado                   4002
# Passei das Águas Shopping           4000
# Shopping União de Osasco            3995
# Iguatemi Esplanada                  3980
# Shopping Barra                      3962
# Shopping Morumbi                    3960
# Parque Dom Pedro Shopping           3902
# Shopping Recife                     3891
# Shopping Midway Mall                3837
# Name: count, dtype: int64
#                                   Valor Final
# ID Loja
# Bourbon Shopping SP                   1726110
# Center Shopping Uberlândia            1668921
# Iguatemi Campinas                     1762419
# Iguatemi Esplanada                    1699681
# Norte Shopping                        1711968
# Novo Shopping Ribeirão Preto          1678225
# Palladium Shopping Curitiba           1721120
# Parque Dom Pedro Shopping             1631630
# Passei das Águas Shopping             1649014
# Ribeirão Shopping                     1707122
# Rio Mar Recife                        1722766
# Rio Mar Shopping Fortaleza            1698430
# Salvador Shopping                     1646739
# Shopping Barra                        1653103
# Shopping Center Interlagos            1640486
# Shopping Center Leste Aricanduva      1682870
# Shopping Eldorado                     1648111
# Shopping Ibirapuera                   1635060
# Shopping Iguatemi Fortaleza           1674824
# Shopping Midway Mall                  1590441
# Shopping Morumbi                      1586444
# Shopping Recife                       1624879
# Shopping SP Market                    1721763
# Shopping União de Osasco              1663770
# Shopping Vila Velha                   1731167

# %% [markdown]
# ### Mesclar 2 dataframes 'parecidos'

# %%
import pandas as pd
gerentes_df = pd.read_excel("Gerentes.xlsx")
# display(gerentes_df)

vendas_df = vendas_df.merge(gerentes_df)
display(vendas_df)
